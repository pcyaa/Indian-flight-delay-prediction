# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Weather.csv")
df2 = pd.read_csv("Delay.csv")

# %%
df1.head()
# Out:
#       date  totalSnow_cm  DewPointC  WindGustKmph  cloudcover  humidity  \
# 0  01-1-18           0.0       14.0          14.0        19.0      76.0
# 1  01-1-18           0.0       15.0          13.0        18.0      81.0
# 2  01-1-18           0.0       15.0          12.0        16.0      85.0
# 3  01-1-18           0.0       16.0          11.0        14.0      89.0
# 4  01-1-18           0.0       16.0          10.0        13.0      84.0
#
#    precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  Time  \
# 0       0.0    1012.0   18.0        10.0           98.0            9.0   0.0
# 1       0.0    1012.0   18.0        10.0           98.0            8.0   1.0
# 2       0.0    1012.0   17.0        10.0           98.0            8.0   2.0
# 3       0.0    1012.0   17.0        10.0           98.0            7.0   3.0
# 4       0.0    1012.0   18.0        10.0           99.0            6.0   4.0
#
#   Airport
# 0     BLR
# 1     BLR
# 2     BLR
# 3     BLR
# 4     BLR

# %%
df2.head()
# Out:
#       Date Departure Airport  Departure Airport Rating (out of 10)  \
# 0  28-1-18               BLR                                   NaN
# 1  28-1-18               CCU                                   NaN
# 2  28-1-18               DEL                                  7.99
# 3  28-1-18               BOM                                  7.29
# 4  28-1-18               BLR                                   NaN
#
#    Departure Airport On Time Rating (out of 10)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           7.3
# 3                                           6.2
# 4                                           NaN
#
#    Departure Airport Service Rating (out of 10) Arrival Airport  \
# 0                                           NaN             DEL
# 1                                           NaN             DEL
# 2                                           9.1             HYD
# ...

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['date', 'totalSnow_cm', 'DewPointC', 'WindGustKmph', 'cloudcover',
#        'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
#        'winddirDegree', 'windspeedKmph', 'Time', 'Airport'],
#       dtype='object')
# Index(['Date', 'Departure Airport', 'Departure Airport Rating (out of 10)',
#        'Departure Airport On Time Rating (out of 10)',
#        'Departure Airport Service Rating (out of 10)', 'Arrival Airport',
#        'Arrival Airport Rating (out of 10)',
#        'Arrival Airport On Time Rating (out of 10)',
#        'Arrival Airport Service Rating (out of 10)', 'Airplane Type',
#        'Expected Departure Time', 'Departure Time', 'Departure Delay',
#        'Duration', 'Expected Arrival Time', 'Arrival Time',
#        'Arrival Time Delay', 'Carrier', 'Carrier Rating (out of 10)',
#        'Carrier Market Share (out of 100)', 'Carrier Load Factor (out of 100)',
#        'Carrier On Time Performance Rating (out of 100)'],
#       dtype='object')

# %%
t = pd.to_datetime(df2.Date+ ' ' + df2['Expected Departure Time'])

# %%
df2['t'] = t

# %%
df2.head()
# Out:
#       Date Departure Airport  Departure Airport Rating (out of 10)  \
# 0  28-1-18               BLR                                   NaN
# 1  28-1-18               CCU                                   NaN
# 2  28-1-18               DEL                                  7.99
# 3  28-1-18               BOM                                  7.29
# 4  28-1-18               BLR                                   NaN
#
#    Departure Airport On Time Rating (out of 10)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           7.3
# 3                                           6.2
# 4                                           NaN
#
#    Departure Airport Service Rating (out of 10) Arrival Airport  \
# 0                                           NaN             DEL
# 1                                           NaN             DEL
# 2                                           9.1             HYD
# ...

# %%
t1 = pd.to_datetime('')
